# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import requests

# %%
try:
    res = requests.get("https://www.worldometers.info/coronavirus/")
except HTTPError as e:
    print(e)

# %%
bs = BeautifulSoup(res.text)

# %%
print(bs.h1)
# Out:
# <h1>Coronavirus Cases:</h1>

# %%
print(bs.html.body.h1)
# Out:
# <h1>Coronavirus Cases:</h1>

# %%
tab = bs.findAll("table")

# %%
tab
# Out:
# [<table class="table table-bordered table-hover main_table_countries" id="main_table_countries_today" style="width:100%;margin-top: 0px !important;display:none;">
#  <thead>
#  <tr>
#  <th width="1%">#</th>
#  <th width="100">Country,<br>Other</br></th>
#  <th width="20">Total<br>Cases</br></th>
#  <th width="30">New<br>Cases</br></th>
#  <th width="30">Total<br>Deaths</br></th>
#  <th width="30">New<br>Deaths</br></th>
#  <th width="30">Total<br>Recovered</br></th>
#  <th width="30">New<br>Recovered</br></th>
#  <th width="30">Active<br>Cases</br></th>
#  <th width="30">Serious,<br>Critical</br></th>
#  <th width="30">Tot Cases/<br/>1M pop</th>
#  <th width="30">Deaths/<br/>1M pop</th>
#  <th width="30">Total<br/>Tests</th>
#  <th width="30">Tests/<br/>
#  <nobr>1M pop</nobr>
#  </th>
#  <th width="30">Population</th>
#  <th style="display:none" width="30">Continent</th>
# ...

# %%
len(tab)
# Out:
# 3

# %%
for name in tab:
    print(name.get_text())
# Out:
# #
# Country,Other
# TotalCases
# NewCases
# TotalDeaths
# NewDeaths
# TotalRecovered
# NewRecovered
# ActiveCases
# Serious,Critical
# Tot Cases/1M pop
# Deaths/1M pop
# TotalTests
# Tests/
# 1M pop
#
# Population
# Continent
# 1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl
# New Cases/1M pop
# New Deaths/1M pop
# Active Cases/1M pop
#
#
#
#
#
#
# North America
#
# 130,847,105
#
# 1,669,358
#
# 126,303,659
#
# 2,874,088
# 7,498
#
#
#
#
#
# North America
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Asia
#
# 221,424,156
# +212
# 1,552,739
# +1
# 205,580,535
# +3,716
# 14,290,882
# 14,733
#
#
#
#
#
# Asia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Europe
#
# 253,047,410
# +1,860
# 2,097,584
# +53
# 248,352,260
# +1,759
# 2,597,566
# 4,559
#
#
#
#
#
# Europe
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# South America
#
# 69,652,726
#
# 1,364,920
#
# 66,628,557
#
# 1,659,249
# 8,953
#
#
#
#
#
# South America
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Oceania
#
# 14,751,199
# +907
# 32,429
#
# 14,555,406
#
# 163,364
# 46
#
#
#
#
#
# ...

# %%
tab1 = bs.findAll({"tr"})

# %%
len(tab1)
# Out:
# 744

# %%
tab1[0]
# Out:
# <tr>
# <th width="1%">#</th>
# <th width="100">Country,<br>Other</br></th>
# <th width="20">Total<br>Cases</br></th>
# <th width="30">New<br>Cases</br></th>
# <th width="30">Total<br>Deaths</br></th>
# <th width="30">New<br>Deaths</br></th>
# <th width="30">Total<br>Recovered</br></th>
# <th width="30">New<br>Recovered</br></th>
# <th width="30">Active<br>Cases</br></th>
# <th width="30">Serious,<br>Critical</br></th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th width="30">Population</th>
# <th style="display:none" width="30">Continent</th>
# <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
# <th width="30">New Cases/1M pop</th>
# <th width="30">New Deaths/1M pop</th>
# <th width="30">Active Cases/1M pop</th>
# </tr>

# %%
tab1[9].findAll({"td"})[1].get_text()
# Out:
# 'USA'

# %%
country = tab1[0].findAll({"th"})[1].get_text()

# %%
country
# Out:
# 'Country,Other'

# %%
totalCases = tab1[0].findAll({"th"})[2].get_text()

# %%
totalCases
# Out:
# 'TotalCases'

# %%
totalDeaths = tab1[0].findAll({"th"})[4].get_text()

# %%
totalDeaths
# Out:
# 'TotalDeaths'

# %%
rows = [country,totalCases,totalDeaths]

# %%
rows
# Out:
# ['Country,Other', 'TotalCases', 'TotalDeaths']

# %%
for result in tab1:
    data = result.findAll('td')

# %%
len(data)
# Out:
# 22

# %%
data
# Out:
# [<td></td>,
#  <td><strong>Total:</strong></td>,
#  <td>702,566,459</td>,
#  <td style="background-color:#FFEEAA; color:#000;">+39,491</td>,
#  <td>6,975,759</td>,
#  <td style="background-color:red; color:#fff">+268</td>,
#  <td>673,463,183</td>,
#  <td style="background-color:#c8e6c9; color:#000">+48,383</td>,
#  <td>22,127,517</td>,
#  <td>36,399</td>,
#  <td>90,132.7</td>,
#  <td>894.9</td>,
#  <td></td>,
#  <td></td>,
#  <td></td>,
#  <td data-continent="all" style="display:none">All</td>,
#  <td>
#  </td>,
#  <td></td>,
#  <td></td>,
#  <td></td>,
#  <td></td>,
#  <td></td>]

# %%
tab1
# Out:
# [<tr>
#  <th width="1%">#</th>
#  <th width="100">Country,<br>Other</br></th>
#  <th width="20">Total<br>Cases</br></th>
#  <th width="30">New<br>Cases</br></th>
#  <th width="30">Total<br>Deaths</br></th>
#  <th width="30">New<br>Deaths</br></th>
#  <th width="30">Total<br>Recovered</br></th>
#  <th width="30">New<br>Recovered</br></th>
#  <th width="30">Active<br>Cases</br></th>
#  <th width="30">Serious,<br>Critical</br></th>
#  <th width="30">Tot Cases/<br/>1M pop</th>
#  <th width="30">Deaths/<br/>1M pop</th>
#  <th width="30">Total<br/>Tests</th>
#  <th width="30">Tests/<br/>
#  <nobr>1M pop</nobr>
#  </th>
#  <th width="30">Population</th>
#  <th style="display:none" width="30">Continent</th>
#  <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
#  <th width="30">New Cases/1M pop</th>
#  <th width="30">New Deaths/1M pop</th>
#  <th width="30">Active Cases/1M pop</th>
#  </tr>,
# ...

# %%
totRows = []
for rows in tab1:
#     row = tab1.findALl("tr")[0]
    totRows.append(rows)

# %%
len(totRows)
# Out:
# 744

# %%
totRows[711]
# Out:
# <tr style="">
# <td style="font-size:12px;color: grey;text-align:center;vertical-align:middle;">207</td>
# <td style="font-weight: bold; font-size:15px; text-align:left;"><a class="mt_a" href="country/liberia/">Liberia</a></td>
# <td style="font-weight: bold; text-align:right">8,090</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="font-weight: bold; text-align:right;">295                                </td>
# <td style="font-weight: bold;
#                                     text-align:right;"></td>
# <td style="font-weight: bold; text-align:right">7,783</td>
# <td style="font-weight: bold; text-align:right;"></td>
# <td style="text-align:right;font-weight:bold;">12</td>
# <td style="font-weight: bold; text-align:right">2</td>
# <td style="font-weight: bold; text-align:right">1,525</td>
# <td style="font-weight: bold; text-align:right">56</td>
# <td style="font-weight: bold; text-align:right">139,824</td>
# ...

# %%
country=[]
totalCases =[]
totalDeaths =[]

for row in tab1[9:232]: 
    try:
        col1= row.findAll("td")[1]      
        if col1 != None:
            country.append(col1)
#     print(col1.get_text())
        col2= row.findAll("td")[2]
        if col2 != None:
            totalCases.append(col2)
#     print(col2.get_text())
        col3= row.findAll("td")[4]
        if col3 != None:
            totalDeaths.append(col3)
#     print(col3.get_text())
   
    except:
        pass

# %%
len(country)
# Out:
# 223

# %%
len(totalCases)
# Out:
# 223

# %%
len(totalDeaths)
# Out:
# 223

# %%
data=[]
for c, tc, td  in zip(country, totalCases, totalDeaths ):
    data.append([c.text, tc.text, td.text])
    print(c.text, tc.text, td.text)
# Out:
# USA 110,818,155 1,194,100
# India 45,025,605 533,448
# France 40,138,560 167,642
# Germany 38,808,771 181,845
# Brazil 38,303,320 709,195
# S. Korea 34,571,873 35,934
# Japan 33,803,572 74,694
# Italy 26,707,734 195,955
# UK 24,885,790 232,112
# Russia 23,875,738 401,945
# Turkey 17,232,066 102,174
# Spain 13,914,811 121,760
# Australia 11,754,909 24,073
# Vietnam 11,624,114 43,206
# Taiwan 10,241,523 19,005
# Argentina 10,081,076 130,699
# Netherlands 8,633,235 22,992
# Mexico 7,702,809 334,958
# Iran 7,625,812 146,767
# Indonesia 6,826,664 161,954
# Poland 6,654,829 120,487
# Colombia 6,390,565 143,138
# Greece 6,101,379 37,869
# Austria 6,081,287 22,542
# Portugal 5,641,679 28,060
# Ukraine 5,557,995 112,418
# Chile 5,345,980 64,497
# Malaysia 5,269,967 37,340
# Canada 4,915,977 57,905
# Belgium 4,856,459 34,376
# Israel 4,841,772 12,707
# DPRK 4,772,813 74
# Thailand 4,765,003 34,547
# Czechia 4,756,789 43,482
# Peru 4,568,225 222,161
# Switzerland 4,449,493 14,452
# ...

# %%
data
# Out:
# [['USA', '110,818,155', '1,194,100                                '],
#  ['India', '45,025,605', '533,448                                '],
#  ['France', '40,138,560', '167,642                                '],
#  ['Germany', '38,808,771', '181,845                                '],
#  ['Brazil', '38,303,320', '709,195                                '],
#  ['S. Korea', '34,571,873', '35,934                                '],
#  ['Japan', '33,803,572', '74,694                                '],
#  ['Italy', '26,707,734', '195,955                                '],
#  ['UK', '24,885,790', '232,112                                '],
#  ['Russia', '23,875,738', '401,945                                '],
#  ['Turkey', '17,232,066', '102,174                                '],
#  ['Spain', '13,914,811', '121,760                                '],
#  ['Australia', '11,754,909', '24,073                                '],
# ...

# %%
import csv
with open('cvCases.csv','w') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %% [markdown]
# # JSON parsing

# %%
import json

# %%
wiki = requests.get("https://en.wikipedia.org/wiki/Main_Page")

# %%
wikisoup = BeautifulSoup(wiki.text)

# %%
wikisoup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-not-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
wikiinfo = wikisoup.findAll(type="application/ld+json")

# %%
data = wikiinfo[0].contents[0]

# %%
data
# Out:
# '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Main Page","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Main_Page","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q5296","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2002-01-26T15:28:12Z","dateModified":"2023-12-12T23:59:34Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/5\\/53\\/Jardin_du_Musee_Rodin_Paris_Le_Penseur_20050402_%2802%29.jpg","headline":"Wikimedia project page"}'

# %%
jsondata = json.loads(data)

# %%
jsondata
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'Article',
#  'name': 'Main Page',
#  'url': 'https://en.wikipedia.org/wiki/Main_Page',
#  'sameAs': 'http://www.wikidata.org/entity/Q5296',
#  'mainEntity': 'http://www.wikidata.org/entity/Q5296',
#  'author': {'@type': 'Organization',
#   'name': 'Contributors to Wikimedia projects'},
#  'publisher': {'@type': 'Organization',
#   'name': 'Wikimedia Foundation, Inc.',
#   'logo': {'@type': 'ImageObject',
#    'url': 'https://www.wikimedia.org/static/images/wmf-hor-googpub.png'}},
#  'datePublished': '2002-01-26T15:28:12Z',
#  'dateModified': '2023-12-12T23:59:34Z',
#  'image': 'https://upload.wikimedia.org/wikipedia/commons/5/53/Jardin_du_Musee_Rodin_Paris_Le_Penseur_20050402_%2802%29.jpg',
#  'headline': 'Wikimedia project page'}

# %%
pageAddress = jsondata['url']

# %%
pageAddress
# Out:
# 'https://en.wikipedia.org/wiki/Main_Page'

# %% [markdown]
# # Get files from cmsc320

# %%
r = requests.get("https://www.cs.umd.edu/class/spring2024/cmsc320-0201/")

# %%
root = BeautifulSoup(r.content)

# %%
links = root.findAll("a")

# %%
links
# Out:
# [<a class="navbar-brand js-scroll-trigger" href="#page-top">
#  <span class="d-block d-lg-none">CMSC 320</span>
#  <span class="d-none d-lg-block">
#  <h6 style="color: #fff;">CMSC 320 - Spring 2024<br/>
#  <h6 style="color: #fff;"> Sections: 0201 </h6>
#
#  <img alt="" class="img-fluid img-profile rounded-circle mx-auto mb-2" src="img/logo1.png"/>
#  </h6></span>
#  </a>,
#  <a class="nav-link js-scroll-trigger" href="#description">Description</a>,
#  <a class="nav-link js-scroll-trigger" href="#schedule">Schedule</a>,
#  <a class="nav-link js-scroll-trigger" href="#staff">Staff and Office hours</a>,
#  <a class="nav-link js-scroll-trigger" href="#classresources">Class Resources</a>,
#  <a href="syllabus/syllabus.pdf" style="color: white;">Syllabus</a>,
#  <a href="https://hbr.org/2023/09/4-skills-the-next-generation-of-data-scientists-needs-to-develop" style="color: #2196F3;" target="_blank">Skills the next generation of data scientists need to know</a>,
# ...

# %%
text = "this is introduction to data science, cmsc320, specifically 320 fall 2021"

# %%
import re

# %%
match = re.search(r"cmsc320",text)
print(match.start())
# Out:
# 38

# %%
match = re.match(r"cmsc320",text)

# %%
print(match)
# Out:
# None

# %%
for match in re.finditer(r"320", text):
    print( match.start() )
# Out:
# 42
# 60

# %%
match = re.findall(r"cmsc320", text)
match
# Out:
# ['cmsc320']
